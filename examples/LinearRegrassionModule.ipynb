# %% [markdown]
# ## Import Module

# %%
from importlib import reload
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '../src'))
import MLFunctions.MLRegressions as lg
reload(lg)
# Out:
# <module 'MLFunctions.MLRegressions' from 'c:\\Users\\cborg\\OneDrive - Microsoft\\40 - Persönlich\\Project Darwin\\MlmplementationsGIT\\ML-Regression\\examples\\../src\\MLFunctions\\MLRegressions.py'>

# %% [markdown]
# ## Generate Demo Data and Plot it, if it is one or two dimensional

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

#Feature Dimensions
dimensions = 2
numberOfSamples = 100
noise = 10

X,Y = lg.getLinearRegressionDemoData(numberOfSamples, dimensions, noise)

lg.plotData(X,Y)
# Out:
# (<Axes3DSubplot:>, <Figure size 432x288 with 1 Axes>)

# %% [markdown]
# ## Min Max Scaling of Data

# %%
X = lg.scaleData(X)
Y = lg.scaleData(Y)

lg.plotData(X,Y)
# Out:
# (<Axes3DSubplot:>, <Figure size 432x288 with 1 Axes>)

# %% [markdown]
# ## Run the Logistic Regression

# %%
from sklearn.model_selection import train_test_split

learningRate = 0.1
iterations = 10000

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33
)

weigths, c = lg.runLinearRegression(X_train, y_train, learningRate, iterations)

# %% [markdown]
# ## Show Plot

# %%
# %matplotlib widget
from matplotlib import pyplot as plt

lg.plotResults(X_test, y_test, weigths, c)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
